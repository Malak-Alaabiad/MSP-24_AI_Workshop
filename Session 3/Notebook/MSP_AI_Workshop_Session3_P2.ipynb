# %% [markdown]
# # House prices Data
#
# 1. First, id and date are not necessary in this data so I'll drop them.
# 2. I want to create an AI model that predicts the price of apartments.

# %%
import pandas as pd
data = pd.read_csv('/content/house_prices.csv')
data.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors waterfront  view  ... grade  sqft_above  sqft_basement  \
# 0      5650     1.0          N     0  ...     7      1180.0            0.0
# 1      7242     2.0          N     0  ...     7      2170.0          400.0
# 2     10000     1.0          N     0  ...     6       770.0            0.0
# 3      5000     1.0          N     0  ...     7      1050.0          910.0
# 4      8080     1.0          N     0  ...     8      1680.0            0.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# # Data Understanding

# %%
data = data.drop(['id', 'date'], axis=1)

# %%
data.head()
# Out:
#     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  221900         3       1.00         1180      5650     1.0          N
# 1  538000         3       2.25         2570      7242     2.0          N
# 2  180000         2       1.00          770     10000     1.0          N
# 3  604000         4       3.00         1960      5000     1.0          N
# 4  510000         3       2.00         1680      8080     1.0          N
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0    Average      7      1180.0            0.0      1955             0
# 1     0    Average      7      2170.0          400.0      1951          1991
# 2     0    Average      6       770.0            0.0      1933             0
# 3     0  Very Good      7      1050.0          910.0      1965             0
# 4     0    Average      8      1680.0            0.0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# 1 ) Remove all messing values

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# 2) Remove duplicates

# %%
data.shape
# Out:
# (21603, 19)

# %%
data = data.drop_duplicates()

# %%
x = data.iloc[:, 1:]
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  view  \
# 0         3       1.00         1180      5650     1.0          N     0
# 1         3       2.25         2570      7242     2.0          N     0
# 2         2       1.00          770     10000     1.0          N     0
# 3         4       3.00         1960      5000     1.0          N     0
# 4         3       2.00         1680      8080     1.0          N     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0    Average      7      1180.0            0.0      1955             0
# 1    Average      7      2170.0          400.0      1951          1991
# 2    Average      6       770.0            0.0      1933             0
# 3  Very Good      7      1050.0          910.0      1965             0
# 4    Average      8      1680.0            0.0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
y = data.iloc[:, 0:1]
y.head()
# Out:
#     price
# 0  221900
# 1  538000
# 2  180000
# 3  604000
# 4  510000

# %%
x = pd.get_dummies(x)
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  grade  \
# 0         3       1.00         1180      5650     1.0     0      7
# 1         3       2.25         2570      7242     2.0     0      7
# 2         2       1.00          770     10000     1.0     0      6
# 3         4       3.00         1960      5000     1.0     0      7
# 4         3       2.00         1680      8080     1.0     0      8
#
#    sqft_above  sqft_basement  yr_built  ...     long  sqft_living15  \
# 0      1180.0            0.0      1955  ... -122.257         1340.0
# 1      2170.0          400.0      1951  ... -122.319         1690.0
# 2       770.0            0.0      1933  ... -122.233         2720.0
# 3      1050.0          910.0      1965  ... -122.393         1360.0
# 4      1680.0            0.0      1987  ... -122.045         1800.0
#
#    sqft_lot15  waterfront_N  waterfront_Y  condition_Average  condition_Fair  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = scaler.fit_transform(x)
x
# Out:
# array([[0.09090909, 0.125     , 0.06716981, ..., 0.        , 0.        ,
#         0.        ],
#        [0.09090909, 0.28125   , 0.17207547, ..., 0.        , 0.        ,
#         0.        ],
#        [0.06060606, 0.125     , 0.03622642, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.        , 0.        ,
#         0.        ],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.        , 0.        ,
#         0.        ],
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.        , 0.        ,
#         0.        ]])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_features = MinMaxScaler()
scaler_label = MinMaxScaler()
y = scaler_label.fit_transform(y)
y
# Out:
# array([[0.01926557],
#        [0.06072131],
#        [0.01377049],
#        ...,
#        [0.04289849],
#        [0.04262295],
#        [0.03278689]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2)

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model1.score(x_test, y_test)
# Out:
# 0.7066733292761549
